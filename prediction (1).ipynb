# %%
##import libs and load the model
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import load_model

##model = load_model('sentiment_analysis_model.h5')

# %%
##Load the IMDB dataset word index
word_index=imdb.get_word_index()
reverse_word_index=dict([(value,key) for (key,value) in word_index.items()])
# Out:
# ...
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from google.colab import drive
drive.mount('/content/drive')
/content/main.py
# Out:
# Mounted at /content/drive

# %%
model=load_model('/content/drive/MyDrive/Colab Notebooks/simple_rnn_imdb.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (32, 500, 128)         │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (32, 128)              │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (32, 1)                │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,313,027 (5.01 MB)
#  Trainable params: 1,313,025 (5.01 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
model.get_weights()
# Out:
# [array([[ 1.59583718e-01, -1.87397450e-01, -1.23481071e+00, ...,
#          -1.24362424e-01, -3.79465252e-01,  6.21571876e-02],
#         [-1.82139613e-02,  8.76850560e-02,  1.03181358e-02, ...,
#           4.64449152e-02,  4.60869968e-02, -1.42383985e-02],
#         [-1.62960887e-01,  2.11719617e-01, -1.23359889e-01, ...,
#           1.24583684e-01,  2.14764159e-02, -1.41433492e-01],
#         ...,
#         [-1.38063493e-04,  7.85266981e-02,  2.30257362e-02, ...,
#           4.23530769e-03,  5.99159189e-02,  5.30905463e-02],
#         [ 6.11631349e-02, -5.01100719e-03,  2.08184123e-02, ...,
#          -3.81177068e-02, -1.50390476e-01,  4.02335860e-02],
#         [ 3.91210895e-03, -5.05289845e-02, -6.86826184e-02, ...,
#          -1.11201219e-02, -3.73165235e-02,  1.02496250e-02]], dtype=float32),
#  array([[-0.17250875,  0.13226356,  0.08635246, ..., -0.03352041,
#           0.05016406, -0.08702105],
#         [ 0.23545049, -0.15193413, -0.01900314, ..., -0.08526063,
# ...

# %%
##Function to decode reviews
def encode_review(encoded_review):
 return' '.join([reverse_word_index.get(i-3,'?') for i in encoded_review])

##Function to preprocess user input
def preprocess_text(text):
  words=text.lower().split()
  encoded_review=[word_index.get(word,2)+3 for word in words]
  padded_review=sequence.pad_sequences([encoded_review], maxlen=500)
  return padded_review

# %%
##Example review for prediction
example_review="Didn't find it bad personally, looked like actors were prepared for their role"
sentiment,score=predict_sentiment(example_review)
print(f'Sentiment: {sentiment}, Score: {score}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Sentiment: Negative, Score: 0.0005929486942477524
